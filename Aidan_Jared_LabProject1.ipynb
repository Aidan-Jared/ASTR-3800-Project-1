# %%
import numpy as np
import matplotlib.pyplot as plt
import Aidan_function as ai
import scipy.stats as sc
# %matplotlib inline

# %% [markdown]
# # A

# %% [markdown]
# #### i

# %%
ai.npRan(61396, 72769, 80764, 1000) #calls the npRan function from Aidan_function
ai.pause()
# Out:
# (array([ 0.06221719,  0.87171653,  0.55388748,  0.74837041,  0.36658209,
#          0.15303988,  0.42451499,  0.46656086,  0.79028662,  0.08159348,
#          0.65452927,  0.46619143,  0.16826719,  0.39246771,  0.22525833,
#          0.38263723,  0.51495454,  0.05828004,  0.42964143,  0.97591911,
#          0.34816988,  0.95537567,  0.31777815,  0.66606726,  0.83315814,
#          0.43164708,  0.52025227,  0.12333888,  0.25990824,  0.40356996,
#          0.95114734,  0.48370562,  0.21632661,  0.34510847,  0.46963889,
#          0.80895176,  0.01415105,  0.97844031,  0.95723875,  0.21208683,
#          0.75321079,  0.49558418,  0.54123319,  0.42903556,  0.14567181,
#          0.60495609,  0.47427675,  0.88224871,  0.28749544,  0.21973693,
#          0.16226008,  0.88287218,  0.76222412,  0.48121908,  0.90237716,
#          0.21894891,  0.59690481,  0.29620512,  0.1695501 ,  0.71420547,
#          0.94920405,  0.64167642,  0.01403403,  0.02486936,  0.16724755,
# ...

# %% [markdown]
# #### ii

# %%
x,y,z = ai.johnRan(6666666,8888888,2222222, 1000) #calls the johnRan function from Aidan_function
ai.pause()

# %% [markdown]
# #### iii

# %%
Z = np.array([ 4., 55., 23., 27., 33., 58., 7., 2., 31., 58., 63., 
               45., 12., 15., 29., 32., 44., 38., 62., 36., 18., 15., 
               55., 34.,  5., 32., 40., 22., 11., 39., 16., 46., 34., 
               47., 55., 62., 28., 40., 21., 37., 24., 16., 25., 10.,
               13., 49., 35., 58., 10., 18., 16., 23., 61., 47.,  0., 
               14., 16., 61., 15., 27., 31., 41., 30., 58., 50., 23.,
               33., 47., 31., 40.,  3., 8., 11., 10., 43., 29., 35., 
               23., 9., 19., 5., 45., 38.,  2., 49.,  24., 56., 19., 
               7., 9., 35., 29.,  9., 24., 22., 13., 2.,13., 21., 32.,
               2., 50., 46., 28., 42., 31., 29., 38., 50., 32., 16., 34., 
               36., 21., 56., 54.,18., 39., 2., 15., 4., 54., 42., 21., 33., 
               56., 59., 42., 20., 47., 47.,40., 51., 21., 24., 10., 29., 11., 
               19., 43., 15., 41., 59., 3., 30., 42.,25., 56., 2., 28., 31., 8., 
               41., 29., 11., 60., 4., 19., 13., 33., 53.,35., 5., 42., 44., 59., 
               21., 10., 50., 3., 18., 29., 61., 59., 38., 37.,0., 29., 1., 41.,
               31., 30., 20., 2., 45.,  53., 57., 23., 35., 3., 22.,23., 38., 
               62., 55., 34., 26., 16., 4., 39., 54., 4., 23., 26., 39., 12.,
               56., 52., 3., 1., 16., 27., 35., 49., 38., 1., 51., 46., 42., 
               10., 22., 3., 34., 39., 43., 31., 35., 12., 3., 39., 46., 5., 
               23., 47., 29., 17.,8., 6., 7., 23., 29., 46., 1., 51., 36., 56.,
               42., 4., 46., 5., 41.,56., 62., 41., 59., 31., 48., 13., 10., 18.,
               55., 35., 23., 19., 34., 14.,41., 10., 8., 33., 29., 42., 6., 16., 
               45., 50., 51., 0., 24., 9., 52.,27., 50., 13., 46., 39., 28., 51., 
               50., 9., 10., 23., 52., 4., 30., 18.,21., 56., 59., 55., 55., 61., 
               0., 34., 36., 44., 33., 23., 30., 6., 61., 4., 5., 5., 43., 5., 60.,
               29., 21., 51., 27., 7., 17., 53., 12., 5.,25., 5., 26., 44., 39., 28.,
               53., 51., 54., 37., 30., 49., 32., 23., 39.,40., 37., 40., 50., 21.,
               38., 5., 2., 54., 57., 15., 3., 50., 45., 62.,62., 37., 6., 34., 45., 
               2., 57., 32., 60., 4., 41., 56., 47., 23., 62.,14., 48., 47., 2., 39.,
               48.,  40., 49., 39., 8., 24., 6., 4., 31., 34.,2., 62., 3., 22., 5., 61., 
               56., 1., 20., 6., 50., 16., 28., 24., 39.,30., 29., 40., 12., 42., 26., 4.,
               40., 29., 49., 18., 34., 15., 59., 7.,11., 40., 54., 43., 52., 42., 49., 30.,
               25., 54., 20., 20., 48., 17., 30.,59., 30., 38., 12., 57., 34., 55., 22., 53.,
               4., 12., 41., 41., 19., 41.,32., 48., 33., 46., 22., 0., 57., 25., 57., 32., 57.,
               2., 35., 29., 14.,16., 56., 1., 10., 34., 3., 10., 20., 18., 26., 31., 25., 25.,
               52., 49.,23., 25., 48., 39., 0., 1., 14., 16., 13., 55., 60., 47., 29., 29., 26.,
               44., 48., 0., 46., 14., 22., 29., 12., 45., 19., 52., 48., 46., 9., 33.,62., 60., 
               27., 51., 15., 9., 12., 34., 61., 11., 27., 7., 12., 44., 40.,31., 18., 54., 45.,
               25., 15., 1., 33., 54., 11., 9., 45., 16., 21., 38.,13., 24., 26., 52., 29., 19.,
               44., 32., 54., 11., 32., 12., 40., 51., 43.,8., 31., 34., 48., 8., 57., 15.,
               57., 10., 25., 15., 57., 39., 62., 50.,54., 18., 13., 37., 17., 55., 29.,
               24., 60., 20., 56., 9., 18., 51., 61.,54., 56., 40., 23., 48., 12., 50.,
               3., 19., 37., 26., 41., 4., 29., 5.,61., 46., 25., 35., 0., 6., 50., 45.,
               15., 1., 38., 26., 23., 8., 7.,34., 44., 26., 45., 56., 33., 17., 20., 17.,
               1., 16., 56., 34., 43., 7.,1., 59., 5., 26., 25., 16., 29., 10., 9., 7.,
               22., 62., 26., 29., 60.,26., 11., 17., 24., 49., 53., 59., 26., 38., 56.,
               40., 28., 5., 34., 58.,16., 47., 57., 5., 32., 37., 21., 58., 0., 51., 41., 
               41., 8., 4., 20.,44., 59., 40., 56., 2., 48., 53., 56., 9., 61., 12., 42., 
               27., 60., 52., 4., 18., 37., 35., 51., 40., 52., 27., 56., 49., 44., 6., 
               46., 41., 37.,50., 42., 14., 6., 29., 28., 57., 24., 14., 46., 22., 26.,
               49., 54., 0.,40., 14., 51., 8., 37., 57., 44., 16., 59., 31., 45., 43.,
               56., 2., 17., 0., 57., 41., 48., 37., 16., 17., 15., 7., 0., 14., 59.,
               38., 34., 15.,39., 44., 26., 56., 36., 48., 11., 11., 25., 10., 32.,
               55., 15., 21., 0., 7., 55., 59., 42., 45., 10., 37., 36., 18., 3., 22.,
               59., 53., 56., 13.,27., 42., 47., 34., 61., 25., 57., 34., 17., 6., 55.,
               5., 28., 1., 47.,47., 29., 41., 0.,  4., 40., 17., 61., 44., 30., 50., 
               36., 53., 24., 41., 34., 42., 20., 26., 40., 61., 36., 8., 26., 41., 46.,
               12., 16., 39.,32., 60., 9., 40., 55., 10., 9., 28., 46., 33., 32., 7., 32.,
               3., 1., 61., 57., 35., 47., 54., 11., 48.,  8., 44., 25., 59., 2., 50., 25.,
               56., 29., 18., 43., 49., 46., 8., 41., 34., 6., 55., 60., 29., 55., 22., 23.,
               56., 61., 2., 54., 10., 36., 61.,34., 12., 7., 25., 28., 33., 42., 9., 48.,
               20., 35., 19., 34., 46., 26., 59., 29., 34., 53., 36., 58., 45., 2., 62.,
               43., 1., 32.,42., 24., 25., 62., 12., 19., 12., 32., 25., 39., 31., 38., 
               42., 5.,60., 21., 19., 57., 53., 39., 19., 9., 3., 16., 42., 39., 16., 
               56., 42., 27., 49., 15., 41., 48., 52., 14., 9., 50., 59., 8., 30.,
               42., 25., 0., 31., 24., 8., 5., 2., 43., 18., 24., 26., 9., 46., 16., 
               60., 3., 0., 15., 38., 8., 36., 32., 44., 20., 14., 53., 49., 20., 24., 
               41., 0., 22., 33., 30., 5., 28., 44., 38., 37., 17., 39., 26., 13., 30., 
               46., 0., 42., 12., 0., 49., 13., 31., 17., 32., 59., 55., 31., 17., 12.])
Z = Z / 64
ai.pause()

# %% [markdown]
# # B

# %% [markdown]
# #### i

# %%
it = 1000
x1,y1,z1=ai.npRan(61396, 72769, 80764, it)
f, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, sharey=True)
f.set_figwidth(15)
ax1.plot(range(it),x1)
ax2.plot(range(it),y1)
ax3.plot(range(it),z1)
ax1.set_title('Fig 1: Numpy Uniform Method')
plt.xlabel("Random Number positon")
ax2.set_ylabel("Random Number")
plt.show()
ai.pause()

# %%
it = 1000
x2,y2,z2 =ai.johnRan(6666666,8888888,2222222, it)
f, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, sharey=True)
f.set_figwidth(15)
ax1.plot(range(it),x2)
ax2.plot(range(it),y2)
ax3.plot(range(it),z2)
ax1.set_title('Fig 2: John von Neumann Method')
plt.xlabel("Random Number positon")
ax2.set_ylabel("Random Number")
plt.show()
ai.pause()

# %%
plt.figure(figsize=(15,5))
plt.plot(range(1000),Z)
plt.title('Fig 3: my random numbers')
plt.xlabel("Random Number positon")
plt.ylabel("Random Number")
plt.show()
ai.pause()

# %% [markdown]
# #### ii

# %%
f, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, sharey=True)
f.set_figwidth(15)
n, bins, patches = ax1.hist(x1, bins=np.arange(0,1.1,.1))
ax2.hist(y1, bins=np.arange(0,1.1,.1))
ax3.hist(z1, bins=np.arange(0,1.1,.1))
ax1.set_title('Fig 4: Numpy Random Histogram (.1 width bins)')
plt.xlabel("Random Number")
ax2.set_ylabel("Amount of Each Random Number")
plt.show()

# %%
f, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, sharey=True)
f.set_figwidth(15)
ax1.hist(x1, bins=np.arange(0,1.025,.025))
ax2.hist(y1, bins=np.arange(0,1.025,.025))
ax3.hist(z1, bins=np.arange(0,1.025,.025))
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), fancybox=True, shadow=True, ncol=5)
ax1.set_title('Fig 5: Numpy Random Histogram (.025 width bins)')
plt.xlabel("Random Number")
ax2.set_ylabel("Amount of Each Random Number")
plt.show()
ai.pause()
# Out:
# C:\Users\Aidan\Anaconda\lib\site-packages\matplotlib\axes\_axes.py:475: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
f, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, sharey=True)
f.set_figwidth(15)
ax1.hist(x2, bins=np.arange(0,1.1,.1))
ax2.hist(y2, bins=np.arange(0,1.1,.1))
ax3.hist(z2, bins=np.arange(0,1.1,.1))
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),fancybox=True, shadow=True, ncol=5)
ax1.set_title('Fig 6: John von Neumann Method Histogram (.1 width bins)')
plt.xlabel("Random Number")
ax2.set_ylabel("Amount of Each Random Number")
plt.show()

# %%
f, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, sharey=True)
f.set_figwidth(15)
ax1.hist(x2, bins=np.arange(0,1.025,.025))
ax2.hist(y2, bins=np.arange(0,1.025,.025))
ax3.hist(z2, bins=np.arange(0,1.025,.025))
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),fancybox=True, shadow=True, ncol=5)
ax1.set_title('Fig 7: John von Neumann Method Histogram (.025 width bins)')
plt.xlabel("Random Number")
ax2.set_ylabel("Amount of Each Random Number")
plt.show()
ai.pause()

# %%
plt.hist(Z, bins=np.arange(0,1.1,.1))
plt.title('Fig 8: My Random Numbers Histogram (.1 width bins)')
plt.xlabel("Random Number")
plt.ylabel("Amount of Each Random Number")
plt.show()

# %%
plt.hist(Z, bins=np.arange(0,1.025,.025))
plt.title('Fig 9: My Random Numbers Histogram (.025 width bins)')
plt.xlabel("Random Number")
plt.ylabel("Amount of Each Random Number")
plt.show()
ai.pause()

# %% [markdown]
# #### iii

# %%
n, bins, patches = plt.hist(x1, bins=np.linspace(0,1,10))
plt.title('Fig 10: Numpy Data First Set 10 bins')
plt.xlabel("Random Number")
plt.ylabel("Amount of Each Random Number")
plt.show()
y=ai.chi(len(bins),n,1000)
print 'chi2:',y
cdf = 1 - sc.chi2.cdf(y,9)
print cdf
ai.serial(x1,it)
# Out:
# chi2: 21.88
# 0.00926717075716
# (0, 0)

# %%
n, bins, patches = plt.hist(x1, bins=np.linspace(0,1,40))
plt.title('Fig 11: Numpy Data First Set 40 bins')
plt.xlabel("Random Number")
plt.ylabel("Amount of Each Random Number")
plt.show()
y=ai.chi(len(bins),n,1000)
print 'chi2:',y
cdf = 1 - sc.chi2.cdf(y,39)
print cdf
# Out:
# chi2: 54.68
# 0.0490010104164

# %%
n, bins, patches = plt.hist(x1, bins=np.linspace(0,1,100))
plt.title('Fig 12: Numpy Data First Set 100 bins')
plt.xlabel("Random Number")
plt.ylabel("Amount of Each Random Number")
plt.show()
y=ai.chi(len(bins),n,1000)
print 'chi2:',y
cdf = 1 - sc.chi2.cdf(y,99)
print cdf
ai.pause()
# Out:
# chi2: 111.0
# 0.192824546264

# %%
n, bins, patches = plt.hist(y1, bins=np.linspace(0,1,10))
plt.title('Fig 13: Numpy Data Second Set 10 bins')
plt.xlabel("Random Number")
plt.ylabel("Amount of Each Random Number")
plt.show()
y=ai.chi(len(bins),n,1000)
print 'chi2:',y
cdf = 1 - sc.chi2.cdf(y,9)
print cdf
ai.serial(y1,it)
# Out:
# chi2: 18.6
# 0.0288171732613
# (0, 0)

# %%
n, bins, patches = plt.hist(y1, bins=np.linspace(0,1,40))
plt.title('Fig 14: Numpy Data Second Set 40 bins')
plt.xlabel("Random Number")
plt.ylabel("Amount of Each Random Number")
plt.show()
y=ai.chi(len(bins),n,1000)
print 'chi2:',y
cdf = 1 - sc.chi2.cdf(y,39)
print cdf
# Out:
# chi2: 37.64
# 0.531889502393

# %%
n, bins, patches = plt.hist(y1, bins=np.linspace(0,1,100))
plt.title('Fig 15: Numpy Data Second Set 100 bins')
plt.xlabel("Random Number")
plt.ylabel("Amount of Each Random Number")
plt.show()
y=ai.chi(len(bins),n,1000)
print 'chi2:',y
cdf = 1 - sc.chi2.cdf(y,99)
print cdf
plt.pause()
# Out:
# chi2: 88.0
# 0.777825462573

# %%
n, bins, patches = plt.hist(z1, bins=np.linspace(0,1,10))
plt.title('Fig 16: Numpy Data Third Set 10 bins')
plt.xlabel("Random Number")
plt.ylabel("Amount of Each Random Number")
plt.show()
y=ai.chi(len(bins),n,1000)
print 'chi2:',y
cdf = 1 - sc.chi2.cdf(y,9)
print cdf
ai.serial(z1,it)
# Out:
# chi2: 26.44
# 0.001730209032
# (0, 0)

# %%
n, bins, patches = plt.hist(z1, bins=np.linspace(0,1,40))
plt.title('Fig 17: Numpy Data Third Set 40 bins')
plt.xlabel("Random Number")
plt.ylabel("Amount of Each Random Number")
plt.show()
y=ai.chi(len(bins),n,1000)
print 'chi2:',y
cdf = 1 - sc.chi2.cdf(y,39)
print cdf
# Out:
# chi2: 51.4
# 0.0882430798061

# %%
n, bins, patches = plt.hist(z1, bins=np.linspace(0,1,100))
plt.title('Fig 18: Numpy Data Third Set 100 bins')
plt.xlabel("Random Number")
plt.ylabel("Amount of Each Random Number")
plt.show()
y=ai.chi(len(bins),n,1000)
print 'chi2:',y
cdf = 1 - sc.chi2.cdf(y,99)
print cdf
ai.pause()
# Out:
# chi2: 140.6
# 0.00382470383514

# %%
n, bins, patches = plt.hist(x2, bins=np.linspace(0,1,10))
plt.title('Fig 19: John von Neumann Method First Set 10 bins')
plt.xlabel("Random Number")
plt.ylabel("Amount of Each Random Number")
plt.show()
y=ai.chi(len(bins),n,1000)
print 'chi2:',y
cdf = 1 - sc.chi2.cdf(y,9)
print cdf
ai.serial(x2,it)
# Out:
# chi2: 30.34
# 0.000383934286839
# (1, 0)

# %%
n, bins, patches = plt.hist(x2, bins=np.linspace(0,1,40))
plt.title('Fig 20: John von Neumann Method First Set 40 bins')
plt.xlabel("Random Number")
plt.ylabel("Amount of Each Random Number")
plt.show()
y=ai.chi(len(bins),n,1000)
print 'chi2:',y
cdf = 1 - sc.chi2.cdf(y,39)
print cdf
# Out:
# chi2: 44.12
# 0.26404493672

# %%
n, bins, patches = plt.hist(x2, bins=np.linspace(0,1,100))
plt.title('Fig 21: John von Neumann Method First Set 100 bins')
plt.xlabel("Random Number")
plt.ylabel("Amount of Each Random Number")
plt.show()
y=ai.chi(len(bins),n,1000)
print 'chi2:',y
cdf = 1 - sc.chi2.cdf(y,99)
print cdf
ai.pause()
# Out:
# chi2: 125.2
# 0.0387314215779

# %%
n, bins, patches = plt.hist(y2, bins=np.linspace(0,1,10))
plt.title('Fig 22: John von Neumann Method Second Set 10 bins')
plt.xlabel("Random Number")
plt.ylabel("Amount of Each Random Number")
plt.show()
y=ai.chi(len(bins),n,1000)
print 'chi2:',y
cdf = 1 - sc.chi2.cdf(y,9)
print cdf
ai.serial(y2,it)
# Out:
# chi2: 23.02
# 0.00615155618782
# (0, 0)

# %%
n, bins, patches = plt.hist(y2, bins=np.linspace(0,1,40))
plt.title('Fig 23: John von Neumann Method Second Set 40 bins')
plt.xlabel("Random Number")
plt.ylabel("Amount of Each Random Number")
plt.show()
y=ai.chi(len(bins),n,1000)
print 'chi2:',y
cdf = 1 - sc.chi2.cdf(y,39)
print cdf
# Out:
# chi2: 42.2
# 0.334346286357

# %%
n, bins, patches = plt.hist(y2, bins=np.linspace(0,1,100))
plt.title('Fig 24: John von Neumann Method Second Set 100 bins')
plt.xlabel("Random Number")
plt.ylabel("Amount of Each Random Number")
plt.show()
y=ai.chi(len(bins),n,1000)
print 'chi2:',y
cdf = 1 - sc.chi2.cdf(y,99)
print cdf
ai.pause()
# Out:
# chi2: 109.2
# 0.22711200755

# %%
n, bins, patches = plt.hist(z2, bins=np.linspace(0,1,10))
plt.title('Fig 25: John von Neumann Method Third Set 10 bins')
plt.xlabel("Random Number")
plt.ylabel("Amount of Each Random Number")
plt.show()
y=ai.chi(len(bins),n,1000)
print 'chi2:',y
cdf = 1 - sc.chi2.cdf(y,9)
print cdf
ai.serial(z2,it)
# Out:
# chi2: 21.18
# 0.0118747338456
# (1, 0)

# %%
n, bins, patches = plt.hist(z2, bins=np.linspace(0,1,40))
plt.title('Fig 26: John von Neumann Method Third Set 40 bins')
plt.xlabel("Random Number")
plt.ylabel("Amount of Each Random Number")
plt.show()
y=ai.chi(len(bins),n,1000)
print 'chi2:',y
cdf = 1 - sc.chi2.cdf(y,39)
print cdf
# Out:
# chi2: 44.04
# 0.26677871144

# %%
n, bins, patches = plt.hist(z2, bins=np.linspace(0,1,100))
plt.title('Fig 27: John von Neumann Method Third Set 100 bins')
plt.xlabel("Random Number")
plt.ylabel("Amount of Each Random Number")
plt.show()
y=ai.chi(len(bins),n,1000)
print 'chi2:',y
cdf = 1 - sc.chi2.cdf(y,99)
print cdf
ai.pause()
# Out:
# chi2: 124.4
# 0.0430045461071

# %%
n, bins, patches = plt.hist(Z, bins=np.linspace(0,1,10))
plt.title('Fig 28: My Random Numbers 10 bins')
plt.xlabel("Random Number")
plt.ylabel("Amount of Each Random Number")
plt.show()
y=ai.chi(len(bins),n,1000)
print 'chi2:',y
cdf = 1 - sc.chi2.cdf(y,9)
print cdf
ai.serial(Z,it)
# Out:
# chi2: 26.06
# 0.00199731268583
# (11, 0)

# %%
n, bins, patches = plt.hist(Z, bins=np.linspace(0,1,40))
plt.title('Fig 29: My Random Numbers 40 bins')
plt.xlabel("Random Number")
plt.ylabel("Amount of Each Random Number")
plt.show()
y=ai.chi(len(bins),n,1000)
print 'chi2:',y
cdf = 1 - sc.chi2.cdf(y,39)
print cdf
# Out:
# chi2: 158.04
# 3.33066907388e-16

# %%
n, bins, patches = plt.hist(Z, bins=np.linspace(0,1,100))
plt.title('Fig 30: My Random Numbers 100 bins')
plt.xlabel("Random Number")
plt.ylabel("Amount of Each Random Number")
plt.show()
print 'chi^2', ai.chi(len(bins),n,1000)
ai.pause()
# Out:
# chi^2 671.6
